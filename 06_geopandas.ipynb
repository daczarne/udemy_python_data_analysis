# %% [markdown]
# # Geo-spatial data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import geopandas as gpd
from shapely.geometry import Point, Polygon 
plt.style.use('ggplot')

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/10-21-2020.csv'

# %%
df_hop = pd.read_csv(url)
df_hop
# Out:
#       FIPS Admin2 Province_State        Country_Region          Last_Update  \
# 0      NaN    NaN            NaN           Afghanistan  2020-10-22 04:24:27
# 1      NaN    NaN            NaN               Albania  2020-10-22 04:24:27
# 2      NaN    NaN            NaN               Algeria  2020-10-22 04:24:27
# 3      NaN    NaN            NaN               Andorra  2020-10-22 04:24:27
# 4      NaN    NaN            NaN                Angola  2020-10-22 04:24:27
# ...    ...    ...            ...                   ...                  ...
# 3963   NaN    NaN        Unknown                 China  2020-10-22 04:24:27
# 3964   NaN    NaN            NaN              Kiribati  2020-10-22 04:24:27
# 3965   NaN    NaN            NaN                 Palau  2020-10-22 04:24:27
# 3966   NaN    NaN   Cook Islands           New Zealand  2020-10-22 04:24:27
# 3967   NaN    NaN            NaN  Summer Olympics 2020  2020-10-22 04:24:27
#
#            Lat       Long_  Confirmed  Deaths  Recovered   Active  \
# 0     33.93911   67.709953      40510    1503      33824   5185.0
# 1     41.15330   20.168300      17948     462      10341   7145.0
# 2     28.03390    1.659600      55081    1880      38482  14719.0
# 3     42.50630    1.521800       3811      63       2470   1278.0
# 4    -11.20270   17.873900       8338     255       3040   5043.0
# ...        ...         ...        ...     ...        ...      ...
# 3963       NaN         NaN          0       0          0      0.0
# 3964  -3.37040 -168.734000          0       0          0      0.0
# 3965   7.51500  134.582500          0       0          0      0.0
# 3966 -21.23670 -159.777700          0       0          0      0.0
# 3967  35.64910  139.773700          0       0          0      0.0
#
#                    Combined_Key  Incidence_Rate  Case-Fatality_Ratio
# 0                   Afghanistan      104.063001             3.705258
# 1                       Albania      623.670860             2.574103
# 2                       Algeria      125.609327             3.413155
# 3                       Andorra     4932.375591             1.653109
# 4                        Angola       25.369476             3.058287
# ...                         ...             ...                  ...
# 3963             Unknown, China        0.000000             0.000000
# 3964                   Kiribati        0.000000             0.000000
# 3965                      Palau        0.000000             0.000000
# 3966  Cook Islands, New Zealand        0.000000             0.000000
# 3967       Summer Olympics 2020        0.000000             0.000000
#
# [3968 rows x 14 columns]

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres')) 
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
world.plot(figsize = (20,8))
# Out:
# <AxesSubplot:>

# %%
world.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   pop_est     177 non-null    int64
#  1   continent   177 non-null    object
#  2   name        177 non-null    object
#  3   iso_a3      177 non-null    object
#  4   gdp_md_est  177 non-null    float64
#  5   geometry    177 non-null    geometry
# dtypes: float64(1), geometry(1), int64(1), object(3)
# memory usage: 8.4+ KB

# %%
world.groupby('continent')['name'].count()
# Out:
# continent
# Africa                     51
# Antarctica                  1
# Asia                       47
# Europe                     39
# North America              18
# Oceania                     7
# Seven seas (open ocean)     1
# South America              13
# Name: name, dtype: int64

# %%
eur_mask = world['continent'] == 'Europe'
world.loc[eur_mask]
# Out:
#        pop_est continent              name iso_a3  gdp_md_est  \
# 18   142257519    Europe            Russia    RUS   3745000.0
# 21     5320045    Europe            Norway    -99    364700.0
# 43    67106161    Europe            France    -99   2699000.0
# 110    9960487    Europe            Sweden    SWE    498100.0
# 111    9549747    Europe           Belarus    BLR    165400.0
# 112   44033874    Europe           Ukraine    UKR    352600.0
# 113   38476269    Europe            Poland    POL   1052000.0
# 114    8754413    Europe           Austria    AUT    416600.0
# 115    9850845    Europe           Hungary    HUN    267600.0
# 116    3474121    Europe           Moldova    MDA     18540.0
# 117   21529967    Europe           Romania    ROU    441000.0
# 118    2823859    Europe         Lithuania    LTU     85620.0
# 119    1944643    Europe            Latvia    LVA     50650.0
# 120    1251581    Europe           Estonia    EST     38700.0
# 121   80594017    Europe           Germany    DEU   3979000.0
# 122    7101510    Europe          Bulgaria    BGR    143100.0
# 123   10768477    Europe            Greece    GRC    290500.0
# 125    3047987    Europe           Albania    ALB     33900.0
# 126    4292095    Europe           Croatia    HRV     94240.0
# 127    8236303    Europe       Switzerland    CHE    496300.0
# 128     594130    Europe        Luxembourg    LUX     58740.0
# 129   11491346    Europe           Belgium    BEL    508600.0
# 130   17084719    Europe       Netherlands    NLD    870800.0
# 131   10839514    Europe          Portugal    PRT    297100.0
# 132   48958159    Europe             Spain    ESP   1690000.0
# 133    5011102    Europe           Ireland    IRL    322000.0
# 141   62137802    Europe             Italy    ITA   2221000.0
# 142    5605948    Europe           Denmark    DNK    264800.0
# 143   64769452    Europe    United Kingdom    GBR   2788000.0
# 144     339747    Europe           Iceland    ISL     16150.0
# 150    1972126    Europe          Slovenia    SVN     68350.0
# 151    5491218    Europe           Finland    FIN    224137.0
# 152    5445829    Europe          Slovakia    SVK    168800.0
# 153   10674723    Europe           Czechia    CZE    350900.0
# 170    3856181    Europe  Bosnia and Herz.    BIH     42530.0
# 171    2103721    Europe         Macedonia    MKD     29520.0
# 172    7111024    Europe            Serbia    SRB    101800.0
# 173     642550    Europe        Montenegro    MNE     10610.0
# 174    1895250    Europe            Kosovo    -99     18490.0
#
#                                               geometry
# 18   MULTIPOLYGON (((178.725 71.099, 180.000 71.516...
# 21   MULTIPOLYGON (((15.143 79.674, 15.523 80.016, ...
# 43   MULTIPOLYGON (((-51.658 4.156, -52.249 3.241, ...
# 110  POLYGON ((11.027 58.856, 11.468 59.432, 12.300...
# 111  POLYGON ((28.177 56.169, 29.230 55.918, 29.372...
# 112  POLYGON ((31.786 52.102, 32.159 52.061, 32.412...
# 113  POLYGON ((23.484 53.912, 23.528 53.470, 23.805...
# 114  POLYGON ((16.980 48.123, 16.904 47.715, 16.341...
# 115  POLYGON ((22.086 48.422, 22.641 48.150, 22.711...
# 116  POLYGON ((26.619 48.221, 26.858 48.368, 27.523...
# 117  POLYGON ((28.234 45.488, 28.680 45.304, 29.150...
# 118  POLYGON ((26.494 55.615, 26.588 55.167, 25.768...
# 119  POLYGON ((27.288 57.475, 27.770 57.244, 27.855...
# 120  POLYGON ((27.981 59.475, 27.981 59.475, 28.132...
# 121  POLYGON ((14.120 53.757, 14.353 53.248, 14.075...
# 122  POLYGON ((22.657 44.235, 22.945 43.824, 23.332...
# 123  MULTIPOLYGON (((26.290 35.300, 26.165 35.005, ...
# 125  POLYGON ((21.020 40.843, 21.000 40.580, 20.675...
# 126  POLYGON ((16.565 46.504, 16.883 46.381, 17.630...
# 127  POLYGON ((9.594 47.525, 9.633 47.348, 9.480 47...
# 128  POLYGON ((6.043 50.128, 6.243 49.902, 6.186 49...
# 129  POLYGON ((6.157 50.804, 6.043 50.128, 5.782 50...
# 130  POLYGON ((6.905 53.482, 7.092 53.144, 6.843 52...
# 131  POLYGON ((-9.035 41.881, -8.672 42.135, -8.264...
# 132  POLYGON ((-7.454 37.098, -7.537 37.429, -7.167...
# 133  POLYGON ((-6.198 53.868, -6.033 53.153, -6.789...
# 141  MULTIPOLYGON (((10.443 46.894, 11.049 46.751, ...
# 142  MULTIPOLYGON (((9.922 54.983, 9.282 54.831, 8....
# 143  MULTIPOLYGON (((-6.198 53.868, -6.954 54.074, ...
# 144  POLYGON ((-14.509 66.456, -14.740 65.809, -13....
# 150  POLYGON ((13.806 46.509, 14.632 46.432, 15.137...
# 151  POLYGON ((28.592 69.065, 28.446 68.365, 29.977...
# 152  POLYGON ((22.558 49.086, 22.281 48.825, 22.086...
# 153  POLYGON ((15.017 51.107, 15.491 50.785, 16.239...
# 170  POLYGON ((18.560 42.650, 17.675 43.029, 17.297...
# 171  POLYGON ((22.381 42.320, 22.881 41.999, 22.952...
# 172  POLYGON ((18.830 45.909, 18.830 45.909, 19.596...
# 173  POLYGON ((20.071 42.589, 19.802 42.500, 19.738...
# 174  POLYGON ((20.590 41.855, 20.523 42.218, 20.284...

# %%
world_new = world[eur_mask]
world_new = world_new.drop(world_new[world_new["name"] == 'Russia'].index)
world_new.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 38 entries, 21 to 174
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   pop_est     38 non-null     int64
#  1   continent   38 non-null     object
#  2   name        38 non-null     object
#  3   iso_a3      38 non-null     object
#  4   gdp_md_est  38 non-null     float64
#  5   geometry    38 non-null     geometry
# dtypes: float64(1), geometry(1), int64(1), object(3)
# memory usage: 2.1+ KB

# %%
world_new.name.sort_values()
# Out:
# 125             Albania
# 114             Austria
# 111             Belarus
# 129             Belgium
# 170    Bosnia and Herz.
# 122            Bulgaria
# 126             Croatia
# 153             Czechia
# 142             Denmark
# 120             Estonia
# 151             Finland
# 43               France
# 121             Germany
# 123              Greece
# 115             Hungary
# 144             Iceland
# 133             Ireland
# 141               Italy
# 174              Kosovo
# 119              Latvia
# 118           Lithuania
# 128          Luxembourg
# 171           Macedonia
# 116             Moldova
# 173          Montenegro
# 130         Netherlands
# 21               Norway
# 113              Poland
# 131            Portugal
# 117             Romania
# 172              Serbia
# 152            Slovakia
# 150            Slovenia
# 132               Spain
# 110              Sweden
# 127         Switzerland
# 112             Ukraine
# 143      United Kingdom
# Name: name, dtype: object

# %%
eu = [
  'Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany',
  'Greece', 'Hungary', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'Poland', 'Portugal',
  'Romania', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'United Kingdom'
]

# %%
world_new = world_new.drop(world_new[~ world_new["name"].isin(eu)].index)
world_new
# Out:
#       pop_est continent            name iso_a3  gdp_md_est  \
# 43   67106161    Europe          France    -99   2699000.0
# 110   9960487    Europe          Sweden    SWE    498100.0
# 113  38476269    Europe          Poland    POL   1052000.0
# 114   8754413    Europe         Austria    AUT    416600.0
# 115   9850845    Europe         Hungary    HUN    267600.0
# 117  21529967    Europe         Romania    ROU    441000.0
# 118   2823859    Europe       Lithuania    LTU     85620.0
# 119   1944643    Europe          Latvia    LVA     50650.0
# 120   1251581    Europe         Estonia    EST     38700.0
# 121  80594017    Europe         Germany    DEU   3979000.0
# 122   7101510    Europe        Bulgaria    BGR    143100.0
# 123  10768477    Europe          Greece    GRC    290500.0
# 126   4292095    Europe         Croatia    HRV     94240.0
# 128    594130    Europe      Luxembourg    LUX     58740.0
# 129  11491346    Europe         Belgium    BEL    508600.0
# 130  17084719    Europe     Netherlands    NLD    870800.0
# 131  10839514    Europe        Portugal    PRT    297100.0
# 132  48958159    Europe           Spain    ESP   1690000.0
# 133   5011102    Europe         Ireland    IRL    322000.0
# 141  62137802    Europe           Italy    ITA   2221000.0
# 142   5605948    Europe         Denmark    DNK    264800.0
# 143  64769452    Europe  United Kingdom    GBR   2788000.0
# 150   1972126    Europe        Slovenia    SVN     68350.0
# 151   5491218    Europe         Finland    FIN    224137.0
# 152   5445829    Europe        Slovakia    SVK    168800.0
# 153  10674723    Europe         Czechia    CZE    350900.0
#
#                                               geometry
# 43   MULTIPOLYGON (((-51.65780 4.15623, -52.24934 3...
# 110  POLYGON ((11.02737 58.85615, 11.46827 59.43239...
# 113  POLYGON ((23.48413 53.91250, 23.52754 53.47012...
# 114  POLYGON ((16.97967 48.12350, 16.90375 47.71487...
# 115  POLYGON ((22.08561 48.42226, 22.64082 48.15024...
# 117  POLYGON ((28.23355 45.48828, 28.67978 45.30403...
# 118  POLYGON ((26.49433 55.61511, 26.58828 55.16718...
# 119  POLYGON ((27.28818 57.47453, 27.77002 57.24426...
# 120  POLYGON ((27.98113 59.47537, 27.98112 59.47537...
# 121  POLYGON ((14.11969 53.75703, 14.35332 53.24817...
# 122  POLYGON ((22.65715 44.23492, 22.94483 43.82379...
# 123  MULTIPOLYGON (((26.29000 35.29999, 26.16500 35...
# 126  POLYGON ((16.56481 46.50375, 16.88252 46.38063...
# 128  POLYGON ((6.04307 50.12805, 6.24275 49.90223, ...
# 129  POLYGON ((6.15666 50.80372, 6.04307 50.12805, ...
# 130  POLYGON ((6.90514 53.48216, 7.09205 53.14404, ...
# 131  POLYGON ((-9.03482 41.88057, -8.67195 42.13469...
# 132  POLYGON ((-7.45373 37.09779, -7.53711 37.42890...
# 133  POLYGON ((-6.19788 53.86757, -6.03299 53.15316...
# 141  MULTIPOLYGON (((10.44270 46.89355, 11.04856 46...
# 142  MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...
# 143  MULTIPOLYGON (((-6.19788 53.86757, -6.95373 54...
# 150  POLYGON ((13.80648 46.50931, 14.63247 46.43182...
# 151  POLYGON ((28.59193 69.06478, 28.44594 68.36461...
# 152  POLYGON ((22.55814 49.08574, 22.28084 48.82539...
# 153  POLYGON ((15.01700 51.10667, 15.49097 50.78473...

# %%
ax1 = world_new.plot(figsize = (20, 8))
ax1.set_ylim(32, 75)
ax1.set_xlim(-18, 35)
# Out:
# (-18.0, 35.0)

# %%
df_hop.columns
# Out:
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key', 'Incidence_Rate', 'Case-Fatality_Ratio'],
#       dtype='object')

# %%
df_hop_eu = df_hop.drop(df_hop[~ df_hop['Country_Region'].isin(eu)].index)
df_hop_eu
# Out:
#       FIPS Admin2                                Province_State  \
# 16     NaN    NaN                                           NaN
# 23     NaN    NaN                                           NaN
# 58     NaN    NaN                                           NaN
# 171    NaN    NaN                                           NaN
# 173    NaN    NaN                                           NaN
# ...    ...    ...                                           ...
# 3948   NaN    NaN  Saint Helena, Ascension and Tristan da Cunha
# 3949   NaN    NaN                                      Scotland
# 3950   NaN    NaN                      Turks and Caicos Islands
# 3951   NaN    NaN                                       Unknown
# 3952   NaN    NaN                                         Wales
#
#       Country_Region          Last_Update      Lat      Long_  Confirmed  \
# 16           Austria  2020-10-22 04:24:27  47.5162  14.550100      69409
# 23           Belgium  2020-10-22 04:24:27  50.8333   4.469936     253386
# 58          Bulgaria  2020-10-22 04:24:27  42.7339  25.485800      33335
# 171          Croatia  2020-10-22 04:24:27  45.1000  15.200000      28287
# 173           Cyprus  2020-10-22 04:24:27  35.1264  33.429900       2966
# ...              ...                  ...      ...        ...        ...
# 3948  United Kingdom  2020-10-22 04:24:27  -7.9467 -14.355900          2
# 3949  United Kingdom  2020-10-22 04:24:27  56.4907  -4.202600      50903
# 3950  United Kingdom  2020-10-22 04:24:27  21.6940 -71.797900        698
# 3951  United Kingdom  2020-10-22 04:24:27      NaN        NaN          0
# 3952  United Kingdom  2020-10-22 04:24:27  52.1307  -3.783700      38361
#
#       Deaths  Recovered    Active  \
# 16       925      52617   15867.0
# 23     10539      21717  221130.0
# 58      1048      17598   14689.0
# 171      393      21435    6459.0
# 173       25       1444    1497.0
# ...      ...        ...       ...
# 3948       0          2       0.0
# 3949    2653          0   48250.0
# 3950       6        689       3.0
# 3951       0          0       0.0
# 3952    1736          0   36625.0
#
#                                            Combined_Key  Incidence_Rate  \
# 16                                              Austria      770.663084
# 23                                              Belgium     2186.319202
# 58                                             Bulgaria      479.747627
# 171                                             Croatia      689.041495
# 173                                              Cyprus      245.659749
# ...                                                 ...             ...
# 3948  Saint Helena, Ascension and Tristan da Cunha, ...             NaN
# 3949                           Scotland, United Kingdom      931.726246
# 3950           Turks and Caicos Islands, United Kingdom     1802.779069
# 3951                            Unknown, United Kingdom             NaN
# 3952                              Wales, United Kingdom     1222.232843
#
#       Case-Fatality_Ratio
# 16               1.332680
# 23               4.159267
# 58               3.143843
# 171              1.389331
# 173              0.842886
# ...                   ...
# 3948                  NaN
# 3949             5.211874
# 3950             0.859599
# 3951                  NaN
# 3952             4.525429
#
# [146 rows x 14 columns]

# %%
cols = [x for x in df_hop_eu.columns if x not in ['Country_Region', 'Lat', 'Long_', 'Confirmed']]
cols
# Out:
# ['FIPS',
#  'Admin2',
#  'Province_State',
#  'Last_Update',
#  'Deaths',
#  'Recovered',
#  'Active',
#  'Combined_Key',
#  'Incidence_Rate',
#  'Case-Fatality_Ratio']

# %%
df_hop_eu = df_hop_eu.drop(cols, axis = 1)
df_hop_eu
# Out:
#       Country_Region      Lat      Long_  Confirmed
# 16           Austria  47.5162  14.550100      69409
# 23           Belgium  50.8333   4.469936     253386
# 58          Bulgaria  42.7339  25.485800      33335
# 171          Croatia  45.1000  15.200000      28287
# 173           Cyprus  35.1264  33.429900       2966
# ...              ...      ...        ...        ...
# 3948  United Kingdom  -7.9467 -14.355900          2
# 3949  United Kingdom  56.4907  -4.202600      50903
# 3950  United Kingdom  21.6940 -71.797900        698
# 3951  United Kingdom      NaN        NaN          0
# 3952  United Kingdom  52.1307  -3.783700      38361
#
# [146 rows x 4 columns]

# %%
df_hop_marker = (df_hop_eu['Confirmed'] / (df_hop_eu['Confirmed'].max()) * 1000)
df_hop_marker
# Out:
# 16       71.724481
# 23      261.838947
# 58       34.447054
# 171      29.230653
# 173       3.064946
#            ...
# 3948      0.002067
# 3949     52.601122
# 3950      0.721285
# 3951      0.000000
# 3952     39.640721
# Name: Confirmed, Length: 146, dtype: float64

# %%
gdf = gpd.GeoDataFrame(
    df_hop_eu,
    geometry = gpd.points_from_xy(
        df_hop_eu.Long_,
        df_hop_eu.Lat
    )
)

# %%
ax1 = world_new.plot(figsize = (20, 8))
ax1.set_ylim(32, 75)
ax1.set_xlim(-18, 35)
gdf.plot(
  ax = ax1,
  color = 'red'
)
# Out:
# <AxesSubplot:>

# %%
ax2 = world_new.plot(figsize = (20, 8))
ax2.set_ylim(32, 75)
ax2.set_xlim(-18, 35)
gdf.plot(
  ax = ax2,
  color = 'red',
  markersize = df_hop_marker,
  alpha = 0.5
)
plt.show()

# %%
# Aggregate so that we get one per country
eu_clean = df_hop_eu.groupby('Country_Region')['Confirmed'].sum().reset_index()
eu_lat = df_hop_eu.groupby('Country_Region')['Lat'].mean().reset_index()
eu_long = df_hop_eu.groupby('Country_Region')['Long_'].mean().reset_index()
eu_clean.set_index('Country_Region', inplace = True)
eu_lat.set_index('Country_Region', inplace = True)
eu_long.set_index('Country_Region', inplace = True)

# %%
eu_clean['Lat'] = eu_lat['Lat']
eu_clean['Long_'] = eu_long['Long_']
eu_clean.loc['United Kingdom', ['Lat']] = 53
eu_clean.loc['United Kingdom', ['Long_']] = -1.3
eu_clean.loc['France', ['Lat']] = 47
eu_clean.loc['France', ['Long_']] = 2
eu_clean.loc['Denmark', ['Lat']] = 55.7
eu_clean.loc['Denmark', ['Long_']] = 9
eu_clean.loc['Netherlands', ['Lat']] = 52.5
eu_clean.loc['Netherlands', ['Long_']] = 5.5

# %%
gdf = gpd.GeoDataFrame(
    eu_clean,
    geometry = gpd.points_from_xy(
        eu_clean.Long_,
        eu_clean.Lat
    )
)

# %%
marker = (eu_clean['Confirmed'] / (eu_clean['Confirmed'].max()) * 1000)

# %%
ax3 = world_new.plot(figsize = (20, 8))
ax3.set_ylim(35, 70)
ax3.set_xlim(-10, 30)
ax3.set_title('Map of Covid-19 Cases in EU Member States')
gdf.plot(
  ax = ax3,
  color = 'red',
  markersize = marker,
  alpha = 0.5
)
plt.show()
